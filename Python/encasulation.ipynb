# %%
class Collage:
    collage_name = "Arya old campus" ##### public variable 
    collage_garden = "yes" # ##### public variable 
    collage_account = "2345678901234" ##### public variable

# %%
clg =Collage()

# %%
clg.collage_account
# Out:
# '2345678901234'

# %%
clg.collage_garden
# Out:
# 'yes'

# %%
clg.collage_name
# Out:
# 'Arya main campus'

# %%
class Collage:
    collage_name = "Arya main campus" ##### public variable 
    collage_garden = "yes" # ##### public variable 
    __collage_account = "2345678901234" ##### private  variable

# %%
clg =Collage()

# %%
clg.__collage_account
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 clg.__collage_account
#
# AttributeError: 'Collage' object has no attribute '__collage_account'

# %%
clg.collage_garden
# Out:
# 'yes'

# %%
clg.collage_name
# Out:
# 'Arya main campus'

# %%
class Collage:
    collage_name = "Arya main campus" ##### public variable 
    _collage_garden = "yes" # ##### protected  variable 
    __collage_account = "2345678901234" ##### private  variable

# %%
clg =Collage()

# %%
clg._collage_garden
# Out:
# 'yes'

# %%
clg.__collage_account
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 clg.__collage_account
#
# AttributeError: 'Collage' object has no attribute '__collage_account'

# %%
class Collage:
    collage_name = "Arya main campus" ##### public variable 
    collage_garden = "yes" # ##### public variable 
    __collage_account = "2345678901234" ##### private  variable 
    
    def display(self, a, b ):
        print(a+b)
        return self.__collage_account
    
    
    
clg =Collage()

# %%
clg.display(a = 10 , b =10 )
# Out:
# 20
# '2345678901234'

# %%
# clg._Collage__collage_account

clg._Collage__collage_account
# Out:
# '2345678901234'
