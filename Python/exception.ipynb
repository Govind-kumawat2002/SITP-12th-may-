# %% [markdown]
# in Python, an exception is an error that happens while a program is running.
# When an exception occurs, Python stops the normal flow of the program and raises an error message

# %%
try:
    pass
except :
    pass
else:
    pass
finally:
    pass

# %%
a = 10 
b = 0 
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 a = 10
#       2 b = 0
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
try:
    a= int(input("enter your first nunber ")) 
    b= int(input("enter your first nunber "))  
    print(a/b)
    
except ZeroDivisionError as e :
    print(e)
except ValueError as e :
    print(e)
# Out:
# invalid literal for int() with base 10: 'bhdbfh'

# %%
try:
    a= int(input("enter your first nunber ")) 
    b= int(input("enter your first nunber "))  
    print(a/b)
    
except Exception as e :
    print(e)
# Out:
# invalid literal for int() with base 10: 'dfghjkl'

# %%
lst = [1,2,2,5]
lst[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 lst = [1,2,2,5]
# ----> 2 lst[8]
#
# IndexError: list index out of range

# %%
try:
    name = "dev"
    number = 10 
    print(name+number)
except TypeError as e :
    print(e)
# Out:
# can only concatenate str (not "int") to str

# %%
try:
    print(lastname)
except NameError as e :
    print(e)
# Out:
# name 'lastname' is not defined

# %%
try:
    lst = [10,1,2,52,2,5,2,5,1]
    lst[12]
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    file = open("demo.txt", "r")
except FileNotFoundError as e :
    print("File not found", e )
# Out:
# File not found [Errno 2] No such file or directory: 'demo.txt'

# %%
try:
    num =int(input("enter your number"))
except ValueError as e :
    print("Invalid input ", e )
else:
    print("your input", num )
# Out:
# Invalid input  invalid literal for int() with base 10: 'sfdg'

# %%
try:
    num =int(input("enter your number"))
except ValueError as e :
    print("Invalid input ", e )
else:
    print("your input", num )
    
finally:
    print("me to hmesa chalunga :- ")
# Out:
# Invalid input  invalid literal for int() with base 10: 'sadfgb'
# me to hmesa chalunga :-

# %% [markdown]
# | Exception             | Description                            |
# | --------------------- | -------------------------------------- |
# | `ZeroDivisionError`   | Number ko 0 se divide karna            |
# | `ValueError`          | Wrong value type dena                  |
# | `TypeError`           | Different incompatible types use karna |
# | `NameError`           | Undefined variable use karna           |
# | `IndexError`          | Invalid list index access karna        |
# | `KeyError`            | Dictionary me missing key access karna |
# | `FileNotFoundError`   | File exist na karna                    |
# | `AttributeError`      | Invalid attribute/method access karna  |
# | `ImportError`         | Module import na hona                  |
# | `ModuleNotFoundError` | Module install na hona                 |

# %%
age = -5 
if age <0:
    raise Exception ("age cannot be negative")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 age = -5
#       2 if age <0:
# ----> 3     raise Exception ("age cannot be negative")
#
# Exception: age cannot be negative

# %%
name = "":
if name =="":
    raise Exception("name cannot be empty ")
# Out:
#   Cell In[25], line 1
#     name = "":
#              ^
# SyntaxError: invalid syntax

# %%
try:
    age = -5
    if age <0:
        raise Exception("age cannot be negative")
except ValueError as e :
    print(e)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[26], line 5
#       1 try:
#       2     age = -5
#       3     if age <0:
#       4         raise Exception("age cannot be negative")
# ----> 5 except ValueError as e :
#       6     print(e)
#       7
#
# Exception: age cannot be negative

# %%
class InvalidAgeError(Exception):
    pass
age = 15
if age <18:
    raise InvalidAgeError(" you are not eligible to vote ")
# Out:
# ---------------------------------------------------------------------------
# InvalidAgeError                           Traceback (most recent call last)
# Cell In[27], line 5
#       1 class InvalidAgeError(Exception):
#       2     pass
#       3 age = 15
#       4 if age <18:
# ----> 5     raise InvalidAgeError(" you are not eligible to vote ")
#
# InvalidAgeError:  you are not eligible to vote

# %%
lst = [ 12,2,2,2]
lst[15]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 lst = [ 12,2,2,2]
# ----> 2 lst[15]
#
# IndexError: list index out of range

# %%
class InvalidAgeError(Exception):
    pass

try:
    age = 17
    if age <18:
        raise InvalidAgeError(" you are not eligible to vote ")
    print("you can vote")
except InvalidAgeError as e:
    print(e)
# Out:
#  you are not eligible to vote

# %%
class Class_name(Exception):
    pass
try:
    bal = 5000
    val = 4000
    if val>bal:
        raise Class_name("bhai tere account me etne pese nhi hai ")
    print("pese bej diye ")
except Class_name as e :
    print(e)
# Out:
# pese bej diye
