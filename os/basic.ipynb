# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\GenerativeAi\\Deep learning'

# %%
path = r'c:\\Users\\kumaw\\OneDrive\\Desktop\\Data Science\\os'
os.listdir(path)
# Out:
# ['basic.ipynb', 'collage']

# %%
path = r"D:\Software\iCare Data Recovery Software 4.5.2 (32+64 bit) + REG. KEY (FULL)\iCare Data Recovery Software 4.5.2 (32+64 bit) + REG. KEY (FULL)\REG. KEY"
os.listdir(path)
# Out:
# ['iCare-MESMERiZE.reg']

# %%
path = r"D:\GenerativeAi\Gen ai\1-Basics+Of+Langchain"
# os.listdir(path)
os.listdir(r"D:\GenerativeAi\Gen ai\1-Basics+Of+Langchain")
# Out:
# ['.env',
#  '.venv',
#  '1.1-openai',
#  '1.2-ollama',
#  '3.2-DataIngestion',
#  '3.3-Data Trnasformer',
#  '4-Embeddings',
#  '5-VectorStore',
#  'Agentic AI',
#  'chatbot_with_history_message',
#  'Fast Api',
#  'genai',
#  'Groq Ai',
#  'projects',
#  'RAG_PROJECTS',
#  'requirements.txt',
#  'Resume Analyzer AI',
#  'Retrivers',
#  'tools']

# %%
# os.mkdir("hello")

# %%
os.getcwd()
# Out:
# 'D:\\GenerativeAi\\Deep learning'

# %%
os.listdir(r'c:\\Users\\kumaw\\OneDrive\\Desktop\\Data Science\\os')
# Out:
# ['basic.ipynb', 'collage']

# %%
print("he")
# Out:
# he

# %%
# os.makedirs("student\\data\\reports")

# %%
os.listdir(os.getcwd())
# Out:
# ['ANN', 'CNN', 'GRU', 'LSTM', 'RNN', 'student']

# %%
# os.rmdir("hello")

# %%
os.listdir(os.getcwd())
# Out:
# ['ANN', 'CNN', 'GRU', 'LSTM', 'RNN', 'student']

# %%
os.rename("student", "collage")

# %%
os.listdir(os.getcwd())
# Out:
# ['ANN', 'CNN', 'collage', 'GRU', 'LSTM', 'RNN']

# %%
os.getcwd()
# Out:
# 'D:\\GenerativeAi\\Deep learning'

# %%
os.chdir(r"D:\GenerativeAi\Deep learning")

# %%
os.listdir(os.getcwd())
# Out:
# ['ANN', 'CNN', 'collage', 'GRU', 'LSTM', 'RNN']

# %%
path = "D:\GenerativeAi\Gen ai\1-Basics+Of+Langchain\.venv\etc\jupyter\nbconfig\notebook.d"

path1 = r"D:\GenerativeAi\Gen ai\1-Basics+Of+Langchain"
path2 = r".venv\etc\jupyter\nbconfig\notebook.d"
complete_path =os.path.join(path1, path2)
print(complete_path)
print("Final output :- ",os.listdir(complete_path))
# Out:
# D:\GenerativeAi\Gen ai\1-Basics+Of+Langchain\.venv\etc\jupyter\nbconfig\notebook.d
# Final output :-  ['pydeck.json']

# %%
os.path.isfile("D:\GenerativeAi\Gen ai\1-Basics+Of+Langchain\.venv\etc\jupyter\nbconfig\notebook.d\pydeck.json")
# Out:
# False

# %%
os.path.isdir("D:\GenerativeAi\Gen ai\1-Basics+Of+Langchain\.venv\etc\jupyter\nbconfig\notebook.d")
# Out:
# False

# %% [markdown]
# | Function           | Work                          | Example                       |
# | ------------------ | ----------------------------- | ----------------------------- |
# | `os.getcwd()`      | Get current working directory | `os.getcwd()`                 |
# | `os.chdir(path)`   | Change current directory      | `os.chdir("D:/Python")`       |
# | `os.listdir()`     | Show all files and folders    | `os.listdir()`                |
# | `os.mkdir()`       | Create one folder             | `os.mkdir("Student")`         |
# | `os.makedirs()`    | Create multiple folders       | `os.makedirs("Data/Student")` |
# | `os.rmdir()`       | Delete empty folder           | `os.rmdir("Student")`         |
# | `os.removedirs()`  | Delete nested empty folders   | `os.removedirs("A/B/C")`      |
# | `os.remove()`      | Delete file                   | `os.remove("data.txt")`       |
# | `os.rename()`      | Rename file/folder            | `os.rename("old","new")`      |
# | `os.path.exists()` | Check file/folder exists      | `os.path.exists("Data")`      |
# | `os.path.isfile()` | Check file exists             | `os.path.isfile("a.txt")`     |
# | `os.path.isdir()`  | Check folder exists           | `os.path.isdir("Student")`    |
# | `os.path.join()`   | Join file paths               | `os.path.join("A","B")`       |

# %%
# os.path.exists()
